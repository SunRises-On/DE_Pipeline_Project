# %%
#Python imports
import datetime
# widely used PostgreSQL connector library
import psycopg2
#pip install psycopg2
import random
from decimal import Decimal

# %%
from restaurant_menu import McDonald_menu, Wingstop_menu, Taco_bell_menu

# %%
delivery_list = ['pickup', 'delivery']

vendor_dict = { 1: McDonald_menu,
             2: Wingstop_menu,
             3: Taco_bell_menu,
    
}

country_code_iso3 = 'USA'
customer_id_list = list(range(1,10001))

RECORDS = 12001
REC_PER_DATE = 100

# %%
tax_list = [0,.029,.04,.04225,.0445,.045,.0475,.05,.053,.055,.056,.0575,.06,.061,.0625,.0635,.065,.06625,.0685,.06875,.07,.0725]

# %%
#establish the connection
conn = psycopg2.connect(
    host="localhost",
    port='5432',
    database="DE",
    user="postgres", 
    password="password")

# %%
#set auto commit 
conn.autocommit = True

# %%
#create a cursor object
cur = conn.cursor()

# %%
def insert(column_names, column_values, cur):
    query = f"""INSERT INTO user_purchase
    ({column_names})
    VALUES
    ({column_values});
    """

    #execute the INSERT statement
    cur.execute(query)

# %%
cur.execute("""SELECT table_name FROM information_schema.tables
       WHERE table_schema = 'public'""")

# %%
#check if table is in database
for table in cur.fetchall():
    print(table)
# Out:
# ('user_purchase',)

# %%
#delete old table
query = """DELETE FROM user_purchase;
"""

# %%
cur.execute(query)

# %%
column_names="vendor_id, delivery_method, menu_items, invoice_date, tax, total, country_code_iso3, customer_id"

# %%
def getMenu(vendor):
    return vendor_dict[vendor]

# %%
#Get the total from the dictionary values
#Since we need precision use Decimal
def getDictTotal(item_dict):
    values_list = item_dict.values()
    total = Decimal(0)
    for value in values_list:
        num = Decimal(value)
        total += num
    return total

# %%
def checkKey(item_dict, key):
    #check if empty
    #empty dictionary are false 
    if (bool(item_dict) == False):
        return False
    elif key in item_dict.keys():
        return True
    else:
        return False

# %%
def addItem(item_dict, menu):
    rnum = random.randrange(0,len(menu))
    print(f"item_dict = {item_dict}")
    print(f"random item = {rnum}")
    key = list(menu)[rnum]
    print(f"key = {key}")
    val = list(menu.values())[rnum]
    print(f"val = {val}")
    temp = {key: val}
    #check if key already in item_dict
    isDuplicate = checkKey(item_dict, key)
    
   # try:
        #if duplicate  
    if(isDuplicate):
        x = item_dict[key]
        
        #check if x is zero
        #if it's zero do nothing
        #add a way to count zero items later
        if(x!=0):
        
            #check number of duplicates
            count = val/x
            #round to nearest integer 
            count = round(count)
            print(f"count = {count}")
            
            #example new burger is now
            # (1) Double Burger
            key = f"({count}) {key}"
            print(f"new key = {key}")
            temp = {key:val}
            print("it is duplicate")
            print(f"item_dict = {item_dict}")
            item_dict = item_dict.update(temp)
            print(f"item_dict = {item_dict}")
    #not duplicate add new key-value pair
    else:
        print(f"key = {key}")
        print(f"val = {val}")
        print(f"item_dict = {item_dict}")
        item_dict[key]=val

    #except (Exception) as error:
    #    print(error)
        
    
    return item_dict

# %%
def getItemList(menu, rnum, item_dict ):
    print("------------------")
    print(f"rnum = {rnum}")
    item_dict = item_dict
    if(rnum > 0):
        item_dict = addItem(item_dict, menu)
        getItemList(menu, rnum-1, item_dict)
    return item_dict

# %%
def print_date(date_obj):
    date_format="%Y-%m-%d"
    print(date_obj.strftime(date_format))

# %%
def increment_date(date_obj):
    date_obj += datetime.timedelta(days=1)
    return date_obj

# %%
def create_date_obj(year, month, day):
    date_obj = datetime.datetime(year, month, day)
    return date_obj

# %%
def get_col_2(start, end):
    rnum = random.randrange(start, end)
    return rnum

# %%
def get_col_3(start, end):
    rnum = random.randrange(0,2)
    delivery_method = delivery_list[rnum]
    return delivery_method

# %%
#get number of items ordered from 1 - end
def get_items_ordered(start, end):
    rnum = random.randrange(start, end)
    return rnum

# %%
def get_csv_from_dict(dictionary):
    new_list = list(dictionary)
    new_csv = '|'.join(new_list)
    return new_csv

# %%
def get_customer_id(rnum):
    customer_id = customer_id_list[rnum]
    return customer_id

# %%
def get_col_9(start, end):
    rnum= random.randrange(start,end)
    customer_id = get_customer_id(rnum)
    return customer_id

# %%
def get_item_dict(vendor_id, start,end):
    
    items_ordered = get_items_ordered(start, end)
    menu_dict = getMenu(vendor_id) #get menu dictionary

    item_dict={}
    item_dict = getItemList(menu_dict,items_ordered, item_dict)
    
    return item_dict

# %%
def get_col_6():
    rnum = random.randrange(0, len(tax_list))
    tax = tax_list[rnum]
    return tax

# %%
def get_col_7(item_dict, tax):
    item_total = getDictTotal(item_dict)
    item_total = round(item_total, 2)

    #convert to decimal
    tax = Decimal(tax)
    item_tax =  item_total* tax
    #round number to closest two decimal places
    item_tax = round(item_tax,2)

    total = item_total + item_tax
    return total

# %%
    

date_obj = create_date_obj(2023,1,1)

for i in range(1,RECORDS):
    
    if((i%REC_PER_DATE) == 0):
        date_obj = increment_date(date_obj)

    vendor_id = get_col_2(1,4)
    col_2=vendor_id
    
    delivery_method = get_col_3(0,2)
    col_3=delivery_method
        
    
    item_dict = get_item_dict(vendor_id, 1,4)
    item_csv = get_csv_from_dict(item_dict)
    col_4=item_csv
    
    col_5=date_obj

    tax = get_col_6()
    col_6= tax
    
    
    total =get_col_7(item_dict, tax)
    col_7=total
    
    col_8=country_code_iso3

    customer_id = get_col_9(0, 10000)
    col_9= customer_id
    
    column_values = f" {col_2} , '{col_3}' , '{col_4}' ,'{col_5}' ,{col_6} ,{col_7} ,'{col_8}', {col_9}"

    
    insert(column_names, column_values, cur)
# Out:
# ------------------
# rnum = 2
# item_dict = {}
# random item = 76
# key = Soft Drinks 20oz
# val = 2.69
# key = Soft Drinks 20oz
# val = 2.69
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Soft Drinks 20oz': 2.69}
# random item = 50
# key = 100 Wings Classic
# val = 114.99
# key = 100 Wings Classic
# val = 114.99
# item_dict = {'Soft Drinks 20oz': 2.69}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 5
# key = Medium 8 pc Wing Combo Classic
# val = 13.29
# key = Medium 8 pc Wing Combo Classic
# val = 13.29
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 21
# key = 50pc Party Pack Boneless
# val = 55.19
# key = 50pc Party Pack Boneless
# val = 55.19
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'50pc Party Pack Boneless': 55.19}
# random item = 47
# key = 75 Wings Classic
# val = 85.49
# key = 75 Wings Classic
# val = 85.49
# item_dict = {'50pc Party Pack Boneless': 55.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 186
# key = Double Cheeseburger
# val = 2.99
# key = Double Cheeseburger
# val = 2.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Double Cheeseburger': 2.99}
# random item = 117
# key = Blueberry Muffin
# val = 2.69
# key = Blueberry Muffin
# val = 2.69
# item_dict = {'Double Cheeseburger': 2.99}
# ------------------
# rnum = 1
# item_dict = {'Double Cheeseburger': 2.99, 'Blueberry Muffin': 2.69}
# random item = 25
# key = Oatmeal
# val = 3.59
# key = Oatmeal
# val = 3.59
# item_dict = {'Double Cheeseburger': 2.99, 'Blueberry Muffin': 2.69}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 86
# key = Iced Pumpkin Coffee
# val = 2.69
# key = Iced Pumpkin Coffee
# val = 2.69
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 162
# key = Medium Dr. Pepper
# val = 1.79
# key = Medium Dr. Pepper
# val = 1.79
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Dr. Pepper': 1.79}
# random item = 154
# key = Regular M&M McFlurry
# val = 4.29
# key = Regular M&M McFlurry
# val = 4.29
# item_dict = {'Medium Dr. Pepper': 1.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 25
# key = Cheesy Gordita Crunch Cravings Trio
# val = 5.0
# key = Cheesy Gordita Crunch Cravings Trio
# val = 5.0
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Cheesy Gordita Crunch Cravings Trio': 5.0}
# random item = 1
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# item_dict = {'Cheesy Gordita Crunch Cravings Trio': 5.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 113
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# random item = 84
# key = Chicken Quesadilla
# val = 6.19
# key = Chicken Quesadilla
# val = 6.19
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 46
# key = 75 Wings Mix & Match
# val = 85.49
# key = 75 Wings Mix & Match
# val = 85.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'75 Wings Mix & Match': 85.49}
# random item = 18
# key = 40pc Group Pack Boneless
# val = 44.09
# key = 40pc Group Pack Boneless
# val = 44.09
# item_dict = {'75 Wings Mix & Match': 85.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 69
# key = Cajun Fried Corn Regular
# val = 3.69
# key = Cajun Fried Corn Regular
# val = 3.69
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Cajun Fried Corn Regular': 3.69}
# random item = 16
# key = 30pc Crew Pack Mix & Match
# val = 41.39
# key = 30pc Crew Pack Mix & Match
# val = 41.39
# item_dict = {'Cajun Fried Corn Regular': 3.69}
# ------------------
# rnum = 1
# item_dict = {'Cajun Fried Corn Regular': 3.69, '30pc Crew Pack Mix & Match': 41.39}
# random item = 69
# key = Cajun Fried Corn Regular
# val = 3.69
# count = 1
# it is duplicate
# item_dict = {'Cajun Fried Corn Regular': 3.69, '30pc Crew Pack Mix & Match': 41.39}
# item_dict = None
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 17
# key = 30pc Crew Pack Classic
# val = 41.39
# key = 30pc Crew Pack Classic
# val = 41.39
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 45
# key = Crispy Chicken Wings
# val = 6.99
# key = Crispy Chicken Wings
# val = 6.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Crispy Chicken Wings': 6.99}
# random item = 53
# key = Fiesta Veggie Burrito
# val = 2.0
# key = Fiesta Veggie Burrito
# val = 2.0
# item_dict = {'Crispy Chicken Wings': 6.99}
# ------------------
# rnum = 1
# item_dict = {'Crispy Chicken Wings': 6.99, 'Fiesta Veggie Burrito': 2.0}
# random item = 76
# key = Reduced-Fat Sour Cream
# val = 0.75
# key = Reduced-Fat Sour Cream
# val = 0.75
# item_dict = {'Crispy Chicken Wings': 6.99, 'Fiesta Veggie Burrito': 2.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 47
# key = 75 Wings Classic
# val = 85.49
# key = 75 Wings Classic
# val = 85.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'75 Wings Classic': 85.49}
# random item = 21
# key = 50pc Party Pack Boneless
# val = 55.19
# key = 50pc Party Pack Boneless
# val = 55.19
# item_dict = {'75 Wings Classic': 85.49}
# ------------------
# rnum = 1
# item_dict = {'75 Wings Classic': 85.49, '50pc Party Pack Boneless': 55.19}
# random item = 52
# key = Large 5 pc Crispy Tender Combo
# val = 11.89
# key = Large 5 pc Crispy Tender Combo
# val = 11.89
# item_dict = {'75 Wings Classic': 85.49, '50pc Party Pack Boneless': 55.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 53
# key = Crispy Chicken Sandwich
# val = 4.79
# key = Crispy Chicken Sandwich
# val = 4.79
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Crispy Chicken Sandwich': 4.79}
# random item = 116
# key = Cheese Danish
# val = 2.59
# key = Cheese Danish
# val = 2.59
# item_dict = {'Crispy Chicken Sandwich': 4.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 21
# key = 50pc Party Pack Boneless
# val = 55.19
# key = 50pc Party Pack Boneless
# val = 55.19
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 63
# key = Cheese Fries Regular
# val = 3.49
# key = Cheese Fries Regular
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Cheese Fries Regular': 3.49}
# random item = 75
# key = Iced Tea 32oz
# val = 3.29
# key = Iced Tea 32oz
# val = 3.29
# item_dict = {'Cheese Fries Regular': 3.49}
# ------------------
# rnum = 1
# item_dict = {'Cheese Fries Regular': 3.49, 'Iced Tea 32oz': 3.29}
# random item = 45
# key = 75 Wings Boneless
# val = 74.49
# key = 75 Wings Boneless
# val = 74.49
# item_dict = {'Cheese Fries Regular': 3.49, 'Iced Tea 32oz': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 85
# key = Steak Quesadilla
# val = 6.29
# key = Steak Quesadilla
# val = 6.29
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Steak Quesadilla': 6.29}
# random item = 50
# key = Burrito Supreme
# val = 5.29
# key = Burrito Supreme
# val = 5.29
# item_dict = {'Steak Quesadilla': 6.29}
# ------------------
# rnum = 1
# item_dict = {'Steak Quesadilla': 6.29, 'Burrito Supreme': 5.29}
# random item = 124
# key = Chips And Nacho Cheese Sauce
# val = 1.69
# key = Chips And Nacho Cheese Sauce
# val = 1.69
# item_dict = {'Steak Quesadilla': 6.29, 'Burrito Supreme': 5.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 130
# key = Splenda Packet
# val = 0.0
# key = Splenda Packet
# val = 0.0
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Splenda Packet': 0.0}
# random item = 70
# key = Bacon Quarter Pounder With Cheese Meal
# val = 8.89
# key = Bacon Quarter Pounder With Cheese Meal
# val = 8.89
# item_dict = {'Splenda Packet': 0.0}
# ------------------
# rnum = 1
# item_dict = {'Splenda Packet': 0.0, 'Bacon Quarter Pounder With Cheese Meal': 8.89}
# random item = 70
# key = Bacon Quarter Pounder With Cheese Meal
# val = 8.89
# count = 1
# it is duplicate
# item_dict = {'Splenda Packet': 0.0, 'Bacon Quarter Pounder With Cheese Meal': 8.89}
# item_dict = None
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 76
# key = 10 Piece McNuggets
# val = 4.89
# key = 10 Piece McNuggets
# val = 4.89
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'10 Piece McNuggets': 4.89}
# random item = 66
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# item_dict = {'10 Piece McNuggets': 4.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 53
# key = 8 pc Meal for 2 – Crispy Tenders
# val = 19.79
# key = 8 pc Meal for 2 – Crispy Tenders
# val = 19.79
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 12
# key = Breakfast Crunchwrap Bacon
# val = 3.29
# key = Breakfast Crunchwrap Bacon
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Breakfast Crunchwrap Bacon': 3.29}
# random item = 29
# key = Nachos BellGrande Combo
# val = 10.19
# key = Nachos BellGrande Combo
# val = 10.19
# item_dict = {'Breakfast Crunchwrap Bacon': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 110
# key = Orange Juice
# val = 1.99
# key = Orange Juice
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Orange Juice': 1.99}
# random item = 14
# key = Hash Brown
# val = 1.0
# key = Hash Brown
# val = 1.0
# item_dict = {'Orange Juice': 1.99}
# ------------------
# rnum = 1
# item_dict = {'Orange Juice': 1.99, 'Hash Brown': 1.0}
# random item = 17
# key = Premium Hot Coffee
# val = 1.99
# key = Premium Hot Coffee
# val = 1.99
# item_dict = {'Orange Juice': 1.99, 'Hash Brown': 1.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 13
# key = 24pc Family Pack Mix & Match
# val = 34.49
# key = 24pc Family Pack Mix & Match
# val = 34.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'24pc Family Pack Mix & Match': 34.49}
# random item = 39
# key = 30 Wings Boneless
# val = 29.89
# key = 30 Wings Boneless
# val = 29.89
# item_dict = {'24pc Family Pack Mix & Match': 34.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 14
# key = 24pc Family Pack Classic
# val = 34.49
# key = 24pc Family Pack Classic
# val = 34.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'24pc Family Pack Classic': 34.49}
# random item = 35
# key = 15 Wings Classic
# val = 17.49
# key = 15 Wings Classic
# val = 17.49
# item_dict = {'24pc Family Pack Classic': 34.49}
# ------------------
# rnum = 1
# item_dict = {'24pc Family Pack Classic': 34.49, '15 Wings Classic': 17.49}
# random item = 16
# key = 30pc Crew Pack Mix & Match
# val = 41.39
# key = 30pc Crew Pack Mix & Match
# val = 41.39
# item_dict = {'24pc Family Pack Classic': 34.49, '15 Wings Classic': 17.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 20
# key = 2 Sausage Burrito Meal
# val = 5.59
# key = 2 Sausage Burrito Meal
# val = 5.59
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'2 Sausage Burrito Meal': 5.59}
# random item = 153
# key = Oreo Fudge McFlurry
# val = 4.29
# key = Oreo Fudge McFlurry
# val = 4.29
# item_dict = {'2 Sausage Burrito Meal': 5.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 63
# key = Cheesy Roll Up
# val = 1.0
# key = Cheesy Roll Up
# val = 1.0
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Cheesy Roll Up': 1.0}
# random item = 76
# key = Reduced-Fat Sour Cream
# val = 0.75
# key = Reduced-Fat Sour Cream
# val = 0.75
# item_dict = {'Cheesy Roll Up': 1.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 74
# key = Iced Tea 20oz
# val = 2.69
# key = Iced Tea 20oz
# val = 2.69
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Iced Tea 20oz': 2.69}
# random item = 17
# key = 30pc Crew Pack Classic
# val = 41.39
# key = 30pc Crew Pack Classic
# val = 41.39
# item_dict = {'Iced Tea 20oz': 2.69}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 14
# key = Hash Brown
# val = 1.0
# key = Hash Brown
# val = 1.0
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Hash Brown': 1.0}
# random item = 73
# key = Fire Sauce Packet
# val = 0.0
# key = Fire Sauce Packet
# val = 0.0
# item_dict = {'Hash Brown': 1.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 20
# key = Iced Cinnabon Delights Coffee
# val = 2.29
# key = Iced Cinnabon Delights Coffee
# val = 2.29
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 28
# key = 100pc Pack Mix & Match
# val = 131.09
# key = 100pc Pack Mix & Match
# val = 131.09
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 96
# key = Medium Caramel Macchiato
# val = 3.29
# key = Medium Caramel Macchiato
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Caramel Macchiato': 3.29}
# random item = 132
# key = Ketchup Packet
# val = 0.0
# key = Ketchup Packet
# val = 0.0
# item_dict = {'Medium Caramel Macchiato': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 66
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Spicy Deluxe Crispy Chicken Sandwich Meal': 8.99}
# random item = 118
# key = Apple Fritter
# val = 2.59
# key = Apple Fritter
# val = 2.59
# item_dict = {'Spicy Deluxe Crispy Chicken Sandwich Meal': 8.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 51
# key = Steak Egg Cheese Bagel
# val = 5.69
# key = Steak Egg Cheese Bagel
# val = 5.69
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Steak Egg Cheese Bagel': 5.69}
# random item = 184
# key = Double Quarter Pounder With Cheese
# val = 7.09
# key = Double Quarter Pounder With Cheese
# val = 7.09
# item_dict = {'Steak Egg Cheese Bagel': 5.69}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 137
# key = Mustard Packet
# val = 0.0
# key = Mustard Packet
# val = 0.0
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 1
# key = Small 6 pc Wing Combo Mix & Match
# val = 11.49
# key = Small 6 pc Wing Combo Mix & Match
# val = 11.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Small 6 pc Wing Combo Mix & Match': 11.49}
# random item = 53
# key = 8 pc Meal for 2 – Crispy Tenders
# val = 19.79
# key = 8 pc Meal for 2 – Crispy Tenders
# val = 19.79
# item_dict = {'Small 6 pc Wing Combo Mix & Match': 11.49}
# ------------------
# rnum = 1
# item_dict = {'Small 6 pc Wing Combo Mix & Match': 11.49, '8 pc Meal for 2 – Crispy Tenders': 19.79}
# random item = 47
# key = 75 Wings Classic
# val = 85.49
# key = 75 Wings Classic
# val = 85.49
# item_dict = {'Small 6 pc Wing Combo Mix & Match': 11.49, '8 pc Meal for 2 – Crispy Tenders': 19.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 87
# key = Mtn Dew Baja Blast Freeze
# val = 3.89
# key = Mtn Dew Baja Blast Freeze
# val = 3.89
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Mtn Dew Baja Blast Freeze': 3.89}
# random item = 49
# key = Beefy 5-Layer Burrito
# val = 3.99
# key = Beefy 5-Layer Burrito
# val = 3.99
# item_dict = {'Mtn Dew Baja Blast Freeze': 3.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 93
# key = Medium Caramel Hot Chocolate
# val = 2.79
# key = Medium Caramel Hot Chocolate
# val = 2.79
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 14
# key = 24pc Family Pack Classic
# val = 34.49
# key = 24pc Family Pack Classic
# val = 34.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'24pc Family Pack Classic': 34.49}
# random item = 28
# key = 100pc Pack Mix & Match
# val = 131.09
# key = 100pc Pack Mix & Match
# val = 131.09
# item_dict = {'24pc Family Pack Classic': 34.49}
# ------------------
# rnum = 1
# item_dict = {'24pc Family Pack Classic': 34.49, '100pc Pack Mix & Match': 131.09}
# random item = 61
# key = Seasoned Fries Regular
# val = 2.79
# key = Seasoned Fries Regular
# val = 2.79
# item_dict = {'24pc Family Pack Classic': 34.49, '100pc Pack Mix & Match': 131.09}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 13
# key = 24pc Family Pack Mix & Match
# val = 34.49
# key = 24pc Family Pack Mix & Match
# val = 34.49
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 11
# key = Breakfast Quesadilla Combo
# val = 4.99
# key = Breakfast Quesadilla Combo
# val = 4.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 48
# key = 100 Wings Boneless
# val = 100.09
# key = 100 Wings Boneless
# val = 100.09
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 62
# key = Seasoned Fries Large
# val = 4.59
# key = Seasoned Fries Large
# val = 4.59
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Seasoned Fries Large': 4.59}
# random item = 35
# key = 15 Wings Classic
# val = 17.49
# key = 15 Wings Classic
# val = 17.49
# item_dict = {'Seasoned Fries Large': 4.59}
# ------------------
# rnum = 1
# item_dict = {'Seasoned Fries Large': 4.59, '15 Wings Classic': 17.49}
# random item = 37
# key = 20 Wings Mix & Match
# val = 22.99
# key = 20 Wings Mix & Match
# val = 22.99
# item_dict = {'Seasoned Fries Large': 4.59, '15 Wings Classic': 17.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 74
# key = Iced Tea 20oz
# val = 2.69
# key = Iced Tea 20oz
# val = 2.69
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 13
# key = Sausage Egg Biscuit Meal
# val = 5.79
# key = Sausage Egg Biscuit Meal
# val = 5.79
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Sausage Egg Biscuit Meal': 5.79}
# random item = 189
# key = Quarter Pounder With Cheese Deluxe
# val = 5.69
# key = Quarter Pounder With Cheese Deluxe
# val = 5.69
# item_dict = {'Sausage Egg Biscuit Meal': 5.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 0
# key = Small 6 pc Wing Combo Boneless
# val = 9.09
# key = Small 6 pc Wing Combo Boneless
# val = 9.09
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Small 6 pc Wing Combo Boneless': 9.09}
# random item = 35
# key = 15 Wings Classic
# val = 17.49
# key = 15 Wings Classic
# val = 17.49
# item_dict = {'Small 6 pc Wing Combo Boneless': 9.09}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 182
# key = Quarter Pounder With Cheese
# val = 5.19
# key = Quarter Pounder With Cheese
# val = 5.19
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 66
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# key = Spicy Deluxe Crispy Chicken Sandwich Meal
# val = 8.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Spicy Deluxe Crispy Chicken Sandwich Meal': 8.99}
# random item = 173
# key = Medium Sweet Iced Tea
# val = 1.49
# key = Medium Sweet Iced Tea
# val = 1.49
# item_dict = {'Spicy Deluxe Crispy Chicken Sandwich Meal': 8.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 2
# key = Small 6 pc Wing Combo Classic
# val = 11.49
# key = Small 6 pc Wing Combo Classic
# val = 11.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49}
# random item = 27
# key = 100pc Pack Boneless
# val = 110.39
# key = 100pc Pack Boneless
# val = 110.39
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 46
# key = 75 Wings Mix & Match
# val = 85.49
# key = 75 Wings Mix & Match
# val = 85.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'75 Wings Mix & Match': 85.49}
# random item = 59
# key = 20 Crispy Tenders
# val = 33.69
# key = 20 Crispy Tenders
# val = 33.69
# item_dict = {'75 Wings Mix & Match': 85.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 7
# key = Large 10 pc Wing Combo Mix & Match
# val = 15.29
# key = Large 10 pc Wing Combo Mix & Match
# val = 15.29
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 22
# key = Egg Biscuit Meal
# val = 3.89
# key = Egg Biscuit Meal
# val = 3.89
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Egg Biscuit Meal': 3.89}
# random item = 147
# key = Ranch Dressing
# val = 0.0
# key = Ranch Dressing
# val = 0.0
# item_dict = {'Egg Biscuit Meal': 3.89}
# ------------------
# rnum = 1
# item_dict = {'Egg Biscuit Meal': 3.89, 'Ranch Dressing': 0.0}
# random item = 183
# key = Double Bacon Quarter Pounder With Cheese
# val = 8.19
# key = Double Bacon Quarter Pounder With Cheese
# val = 8.19
# item_dict = {'Egg Biscuit Meal': 3.89, 'Ranch Dressing': 0.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 109
# key = Cup Of Water
# val = 0.0
# key = Cup Of Water
# val = 0.0
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Cup Of Water': 0.0}
# random item = 104
# key = Sierra Mist
# val = 2.89
# key = Sierra Mist
# val = 2.89
# item_dict = {'Cup Of Water': 0.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 23
# key = 50pc Party Pack Classic
# val = 65.59
# key = 50pc Party Pack Classic
# val = 65.59
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 66
# key = Louisiana Voodoo Fries Large
# val = 6.09
# key = Louisiana Voodoo Fries Large
# val = 6.09
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 1
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49}
# random item = 37
# key = 3 Soft Tacos Supreme Combo
# val = 9.99
# key = 3 Soft Tacos Supreme Combo
# val = 9.99
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 103
# key = Medium Latte
# val = 3.29
# key = Medium Latte
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Medium Latte': 3.29}
# random item = 85
# key = 6 Pieces Chicken McNuggets – Happy Meal
# val = 4.99
# key = 6 Pieces Chicken McNuggets – Happy Meal
# val = 4.99
# item_dict = {'Medium Latte': 3.29}
# ------------------
# rnum = 1
# item_dict = {'Medium Latte': 3.29, '6 Pieces Chicken McNuggets – Happy Meal': 4.99}
# random item = 60
# key = Medium French Fries
# val = 3.59
# key = Medium French Fries
# val = 3.59
# item_dict = {'Medium Latte': 3.29, '6 Pieces Chicken McNuggets – Happy Meal': 4.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 27
# key = Mexican Pizza Combo
# val = 9.89
# key = Mexican Pizza Combo
# val = 9.89
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 157
# key = Plain Sundae
# val = 3.49
# key = Plain Sundae
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 114
# key = Medium Caramel Cappuccino
# val = 3.29
# key = Medium Caramel Cappuccino
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Caramel Cappuccino': 3.29}
# random item = 58
# key = 20 Pieces McNuggets
# val = 6.89
# key = 20 Pieces McNuggets
# val = 6.89
# item_dict = {'Medium Caramel Cappuccino': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 140
# key = Syrup
# val = 0.2
# key = Syrup
# val = 0.2
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Syrup': 0.2}
# random item = 108
# key = Medium Iced Hazelnut Latte
# val = 3.29
# key = Medium Iced Hazelnut Latte
# val = 3.29
# item_dict = {'Syrup': 0.2}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 46
# key = 75 Wings Mix & Match
# val = 85.49
# key = 75 Wings Mix & Match
# val = 85.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'75 Wings Mix & Match': 85.49}
# random item = 39
# key = 30 Wings Boneless
# val = 29.89
# key = 30 Wings Boneless
# val = 29.89
# item_dict = {'75 Wings Mix & Match': 85.49}
# ------------------
# rnum = 1
# item_dict = {'75 Wings Mix & Match': 85.49, '30 Wings Boneless': 29.89}
# random item = 48
# key = 100 Wings Boneless
# val = 100.09
# key = 100 Wings Boneless
# val = 100.09
# item_dict = {'75 Wings Mix & Match': 85.49, '30 Wings Boneless': 29.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 26
# key = Apple Slices
# val = 0.89
# key = Apple Slices
# val = 0.89
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Apple Slices': 0.89}
# random item = 191
# key = Double Hamburger
# val = 2.59
# key = Double Hamburger
# val = 2.59
# item_dict = {'Apple Slices': 0.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 75
# key = Nacho Cheese Sauce
# val = 0.8
# key = Nacho Cheese Sauce
# val = 0.8
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Nacho Cheese Sauce': 0.8}
# random item = 61
# key = Cheesy Gordita Crunch
# val = 4.79
# key = Cheesy Gordita Crunch
# val = 4.79
# item_dict = {'Nacho Cheese Sauce': 0.8}
# ------------------
# rnum = 1
# item_dict = {'Nacho Cheese Sauce': 0.8, 'Cheesy Gordita Crunch': 4.79}
# random item = 68
# key = Black Beans And Rice
# val = 1.79
# key = Black Beans And Rice
# val = 1.79
# item_dict = {'Nacho Cheese Sauce': 0.8, 'Cheesy Gordita Crunch': 4.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 108
# key = Medium Iced Hazelnut Latte
# val = 3.29
# key = Medium Iced Hazelnut Latte
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Medium Iced Hazelnut Latte': 3.29}
# random item = 169
# key = Honest Kids Organic Apple Juice
# val = 1.49
# key = Honest Kids Organic Apple Juice
# val = 1.49
# item_dict = {'Medium Iced Hazelnut Latte': 3.29}
# ------------------
# rnum = 1
# item_dict = {'Medium Iced Hazelnut Latte': 3.29, 'Honest Kids Organic Apple Juice': 1.49}
# random item = 76
# key = 10 Piece McNuggets
# val = 4.89
# key = 10 Piece McNuggets
# val = 4.89
# item_dict = {'Medium Iced Hazelnut Latte': 3.29, 'Honest Kids Organic Apple Juice': 1.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 69
# key = Pintos N Cheese
# val = 2.19
# key = Pintos N Cheese
# val = 2.19
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Pintos N Cheese': 2.19}
# random item = 52
# key = Beefy Melt Burrito
# val = 2.0
# key = Beefy Melt Burrito
# val = 2.0
# item_dict = {'Pintos N Cheese': 2.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 87
# key = Medium Premium Roast Coffee
# val = 1.99
# key = Medium Premium Roast Coffee
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Medium Premium Roast Coffee': 1.99}
# random item = 49
# key = Bacon Egg Cheese Bagel
# val = 4.59
# key = Bacon Egg Cheese Bagel
# val = 4.59
# item_dict = {'Medium Premium Roast Coffee': 1.99}
# ------------------
# rnum = 1
# item_dict = {'Medium Premium Roast Coffee': 1.99, 'Bacon Egg Cheese Bagel': 4.59}
# random item = 172
# key = Medium Frozen Fanta (Wild Cherry)
# val = 2.09
# key = Medium Frozen Fanta (Wild Cherry)
# val = 2.09
# item_dict = {'Medium Premium Roast Coffee': 1.99, 'Bacon Egg Cheese Bagel': 4.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 9
# key = Breakfast Quesadilla Bacon
# val = 2.89
# key = Breakfast Quesadilla Bacon
# val = 2.89
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Breakfast Quesadilla Bacon': 2.89}
# random item = 5
# key = Grande Toasted Breakfast Burrito Sausage
# val = 3.29
# key = Grande Toasted Breakfast Burrito Sausage
# val = 3.29
# item_dict = {'Breakfast Quesadilla Bacon': 2.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 101
# key = Medium Iced Caramel Mocha
# val = 3.49
# key = Medium Iced Caramel Mocha
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Iced Caramel Mocha': 3.49}
# random item = 160
# key = Medium Sprite
# val = 1.79
# key = Medium Sprite
# val = 1.79
# item_dict = {'Medium Iced Caramel Mocha': 3.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 36
# key = 20 Wings Boneless
# val = 20.49
# key = 20 Wings Boneless
# val = 20.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'20 Wings Boneless': 20.49}
# random item = 48
# key = 100 Wings Boneless
# val = 100.09
# key = 100 Wings Boneless
# val = 100.09
# item_dict = {'20 Wings Boneless': 20.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 16
# key = Egg McMuffin Meal
# val = 6.49
# key = Egg McMuffin Meal
# val = 6.49
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 113
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# random item = 22
# key = My Cravings Box
# val = 5.0
# key = My Cravings Box
# val = 5.0
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# ------------------
# rnum = 1
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19, 'My Cravings Box': 5.0}
# random item = 77
# key = Creamy Jalapeno Sauce
# val = 0.1
# key = Creamy Jalapeno Sauce
# val = 0.1
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19, 'My Cravings Box': 5.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 25
# key = Oatmeal
# val = 3.59
# key = Oatmeal
# val = 3.59
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Oatmeal': 3.59}
# random item = 135
# key = Hot Mustard Dipping Sauce
# val = 0.0
# key = Hot Mustard Dipping Sauce
# val = 0.0
# item_dict = {'Oatmeal': 3.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 66
# key = Chips and Nacho Cheese Sauce
# val = 2.19
# key = Chips and Nacho Cheese Sauce
# val = 2.19
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Chips and Nacho Cheese Sauce': 2.19}
# random item = 48
# key = Bean Burrito
# val = 1.59
# key = Bean Burrito
# val = 1.59
# item_dict = {'Chips and Nacho Cheese Sauce': 2.19}
# ------------------
# rnum = 1
# item_dict = {'Chips and Nacho Cheese Sauce': 2.19, 'Bean Burrito': 1.59}
# random item = 34
# key = 3 Doritos Locos Tacos Combo
# val = 8.89
# key = 3 Doritos Locos Tacos Combo
# val = 8.89
# item_dict = {'Chips and Nacho Cheese Sauce': 2.19, 'Bean Burrito': 1.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 39
# key = 30 Wings Boneless
# val = 29.89
# key = 30 Wings Boneless
# val = 29.89
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 115
# key = Supreme Taco Party Pack
# val = 27.99
# key = Supreme Taco Party Pack
# val = 27.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 198
# key = Hot & Spicy McChicken
# val = 3.19
# key = Hot & Spicy McChicken
# val = 3.19
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Hot & Spicy McChicken': 3.19}
# random item = 177
# key = Smoky BLT Quarter Pounder With Cheese
# val = 7.19
# key = Smoky BLT Quarter Pounder With Cheese
# val = 7.19
# item_dict = {'Hot & Spicy McChicken': 3.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 94
# key = Medium Mocha Frappe
# val = 3.99
# key = Medium Mocha Frappe
# val = 3.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Mocha Frappe': 3.99}
# random item = 176
# key = Medium Mango Pineapple Smoothie
# val = 3.69
# key = Medium Mango Pineapple Smoothie
# val = 3.69
# item_dict = {'Medium Mocha Frappe': 3.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 0
# key = Bell Breakfast Box
# val = 6.0
# key = Bell Breakfast Box
# val = 6.0
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 77
# key = Creamy Jalapeno Sauce
# val = 0.1
# key = Creamy Jalapeno Sauce
# val = 0.1
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Creamy Jalapeno Sauce': 0.1}
# random item = 33
# key = 3 Crunchy Tacos Supreme Combo
# val = 9.99
# key = 3 Crunchy Tacos Supreme Combo
# val = 9.99
# item_dict = {'Creamy Jalapeno Sauce': 0.1}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 22
# key = My Cravings Box
# val = 5.0
# key = My Cravings Box
# val = 5.0
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 121
# key = White Hot Ranch Fries Veggie
# val = 2.99
# key = White Hot Ranch Fries Veggie
# val = 2.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'White Hot Ranch Fries Veggie': 2.99}
# random item = 22
# key = My Cravings Box
# val = 5.0
# key = My Cravings Box
# val = 5.0
# item_dict = {'White Hot Ranch Fries Veggie': 2.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 165
# key = Medium Minute Maid Orange Juice
# val = 3.29
# key = Medium Minute Maid Orange Juice
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Medium Minute Maid Orange Juice': 3.29}
# random item = 105
# key = Medium Hazelnut Latte
# val = 3.29
# key = Medium Hazelnut Latte
# val = 3.29
# item_dict = {'Medium Minute Maid Orange Juice': 3.29}
# ------------------
# rnum = 1
# item_dict = {'Medium Minute Maid Orange Juice': 3.29, 'Medium Hazelnut Latte': 3.29}
# random item = 14
# key = McChicken Biscuit Meal
# val = 4.69
# key = McChicken Biscuit Meal
# val = 4.69
# item_dict = {'Medium Minute Maid Orange Juice': 3.29, 'Medium Hazelnut Latte': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 71
# key = Quarter Pounder With Cheese Deluxe Meal
# val = 8.79
# key = Quarter Pounder With Cheese Deluxe Meal
# val = 8.79
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Quarter Pounder With Cheese Deluxe Meal': 8.79}
# random item = 150
# key = Medium Chocolate Shake
# val = 3.69
# key = Medium Chocolate Shake
# val = 3.69
# item_dict = {'Quarter Pounder With Cheese Deluxe Meal': 8.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 80
# key = Avocado Ranch Sauce
# val = 0.2
# key = Avocado Ranch Sauce
# val = 0.2
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 24
# key = Crunchwrap Supreme Cravings Trio
# val = 5.0
# key = Crunchwrap Supreme Cravings Trio
# val = 5.0
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Crunchwrap Supreme Cravings Trio': 5.0}
# random item = 43
# key = Black Bean Crispy Melt Taco
# val = 2.59
# key = Black Bean Crispy Melt Taco
# val = 2.59
# item_dict = {'Crunchwrap Supreme Cravings Trio': 5.0}
# ------------------
# rnum = 1
# item_dict = {'Crunchwrap Supreme Cravings Trio': 5.0, 'Black Bean Crispy Melt Taco': 2.59}
# random item = 47
# key = Spicy Double Steak Grilled Cheese Burrito
# val = 6.99
# key = Spicy Double Steak Grilled Cheese Burrito
# val = 6.99
# item_dict = {'Crunchwrap Supreme Cravings Trio': 5.0, 'Black Bean Crispy Melt Taco': 2.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 15
# key = 30pc Crew Pack Boneless
# val = 33.59
# key = 30pc Crew Pack Boneless
# val = 33.59
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'30pc Crew Pack Boneless': 33.59}
# random item = 19
# key = 40pc Group Pack Mix & Match
# val = 52.89
# key = 40pc Group Pack Mix & Match
# val = 52.89
# item_dict = {'30pc Crew Pack Boneless': 33.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 186
# key = Double Cheeseburger
# val = 2.99
# key = Double Cheeseburger
# val = 2.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 13
# key = 24pc Family Pack Mix & Match
# val = 34.49
# key = 24pc Family Pack Mix & Match
# val = 34.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'24pc Family Pack Mix & Match': 34.49}
# random item = 34
# key = 15 Wings Mix & Match
# val = 17.49
# key = 15 Wings Mix & Match
# val = 17.49
# item_dict = {'24pc Family Pack Mix & Match': 34.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 101
# key = Medium Iced Caramel Mocha
# val = 3.49
# key = Medium Iced Caramel Mocha
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 114
# key = Taco & Burrito Cravings Pack
# val = 17.49
# key = Taco & Burrito Cravings Pack
# val = 17.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Taco & Burrito Cravings Pack': 17.49}
# random item = 106
# key = Brisk Mango Fiesta
# val = 2.89
# key = Brisk Mango Fiesta
# val = 2.89
# item_dict = {'Taco & Burrito Cravings Pack': 17.49}
# ------------------
# rnum = 1
# item_dict = {'Taco & Burrito Cravings Pack': 17.49, 'Brisk Mango Fiesta': 2.89}
# random item = 70
# key = Cinnamon Twists
# val = 1.0
# key = Cinnamon Twists
# val = 1.0
# item_dict = {'Taco & Burrito Cravings Pack': 17.49, 'Brisk Mango Fiesta': 2.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 23
# key = 50pc Party Pack Classic
# val = 65.59
# key = 50pc Party Pack Classic
# val = 65.59
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 51
# key = Steak Egg Cheese Bagel
# val = 5.69
# key = Steak Egg Cheese Bagel
# val = 5.69
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Steak Egg Cheese Bagel': 5.69}
# random item = 75
# key = 6 Piece McNuggets
# val = 2.89
# key = 6 Piece McNuggets
# val = 2.89
# item_dict = {'Steak Egg Cheese Bagel': 5.69}
# ------------------
# rnum = 1
# item_dict = {'Steak Egg Cheese Bagel': 5.69, '6 Piece McNuggets': 2.89}
# random item = 157
# key = Plain Sundae
# val = 3.49
# key = Plain Sundae
# val = 3.49
# item_dict = {'Steak Egg Cheese Bagel': 5.69, '6 Piece McNuggets': 2.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 2
# key = Small 6 pc Wing Combo Classic
# val = 11.49
# key = Small 6 pc Wing Combo Classic
# val = 11.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49}
# random item = 35
# key = 15 Wings Classic
# val = 17.49
# key = 15 Wings Classic
# val = 17.49
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49}
# ------------------
# rnum = 1
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49, '15 Wings Classic': 17.49}
# random item = 58
# key = 15 Crispy Tenders
# val = 24.49
# key = 15 Crispy Tenders
# val = 24.49
# item_dict = {'Small 6 pc Wing Combo Classic': 11.49, '15 Wings Classic': 17.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 58
# key = Black Bean Chalupa Supreme
# val = 3.49
# key = Black Bean Chalupa Supreme
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Black Bean Chalupa Supreme': 3.49}
# random item = 65
# key = Cheesy Fiesta Potatoes
# val = 1.79
# key = Cheesy Fiesta Potatoes
# val = 1.79
# item_dict = {'Black Bean Chalupa Supreme': 3.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 60
# key = Black Bean Crunchwrap Supreme
# val = 4.39
# key = Black Bean Crunchwrap Supreme
# val = 4.39
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Black Bean Crunchwrap Supreme': 4.39}
# random item = 58
# key = Black Bean Chalupa Supreme
# val = 3.49
# key = Black Bean Chalupa Supreme
# val = 3.49
# item_dict = {'Black Bean Crunchwrap Supreme': 4.39}
# ------------------
# rnum = 1
# item_dict = {'Black Bean Crunchwrap Supreme': 4.39, 'Black Bean Chalupa Supreme': 3.49}
# random item = 92
# key = Pepsi
# val = 2.89
# key = Pepsi
# val = 2.89
# item_dict = {'Black Bean Crunchwrap Supreme': 4.39, 'Black Bean Chalupa Supreme': 3.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 64
# key = Cheese Fries Large
# val = 5.79
# key = Cheese Fries Large
# val = 5.79
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 51
# key = Small 3 pc Crispy Tender Combo
# val = 9.59
# key = Small 3 pc Crispy Tender Combo
# val = 9.59
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Small 3 pc Crispy Tender Combo': 9.59}
# random item = 77
# key = Soft Drinks 32oz
# val = 3.29
# key = Soft Drinks 32oz
# val = 3.29
# item_dict = {'Small 3 pc Crispy Tender Combo': 9.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 6
# key = Large 10 pc Wing Combo Boneless
# val = 12.29
# key = Large 10 pc Wing Combo Boneless
# val = 12.29
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 39
# key = 30 Wings Boneless
# val = 29.89
# key = 30 Wings Boneless
# val = 29.89
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'30 Wings Boneless': 29.89}
# random item = 4
# key = Medium 8 pc Wing Combo Mix & Match
# val = 13.29
# key = Medium 8 pc Wing Combo Mix & Match
# val = 13.29
# item_dict = {'30 Wings Boneless': 29.89}
# ------------------
# rnum = 1
# item_dict = {'30 Wings Boneless': 29.89, 'Medium 8 pc Wing Combo Mix & Match': 13.29}
# random item = 59
# key = 20 Crispy Tenders
# val = 33.69
# key = 20 Crispy Tenders
# val = 33.69
# item_dict = {'30 Wings Boneless': 29.89, 'Medium 8 pc Wing Combo Mix & Match': 13.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 110
# key = Orange Juice
# val = 1.99
# key = Orange Juice
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 50
# key = 100 Wings Classic
# val = 114.99
# key = 100 Wings Classic
# val = 114.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 191
# key = Double Hamburger
# val = 2.59
# key = Double Hamburger
# val = 2.59
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 119
# key = 1 Cookie
# val = 1.99
# key = 1 Cookie
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'1 Cookie': 1.99}
# random item = 165
# key = Medium Minute Maid Orange Juice
# val = 3.29
# key = Medium Minute Maid Orange Juice
# val = 3.29
# item_dict = {'1 Cookie': 1.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 43
# key = 50 Wings Mix & Match
# val = 57.49
# key = 50 Wings Mix & Match
# val = 57.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'50 Wings Mix & Match': 57.49}
# random item = 25
# key = 75pc Pack Mix & Match
# val = 100.09
# key = 75pc Pack Mix & Match
# val = 100.09
# item_dict = {'50 Wings Mix & Match': 57.49}
# ------------------
# rnum = 1
# item_dict = {'50 Wings Mix & Match': 57.49, '75pc Pack Mix & Match': 100.09}
# random item = 29
# key = 100pc Pack Classic
# val = 131.09
# key = 100pc Pack Classic
# val = 131.09
# item_dict = {'50 Wings Mix & Match': 57.49, '75pc Pack Mix & Match': 100.09}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 165
# key = Medium Minute Maid Orange Juice
# val = 3.29
# key = Medium Minute Maid Orange Juice
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Medium Minute Maid Orange Juice': 3.29}
# random item = 86
# key = Iced Pumpkin Coffee
# val = 2.69
# key = Iced Pumpkin Coffee
# val = 2.69
# item_dict = {'Medium Minute Maid Orange Juice': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 55
# key = Big Mac Meal
# val = 8.99
# key = Big Mac Meal
# val = 8.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Big Mac Meal': 8.99}
# random item = 34
# key = Hot N Spicy McChicken Biscuit
# val = 1.69
# key = Hot N Spicy McChicken Biscuit
# val = 1.69
# item_dict = {'Big Mac Meal': 8.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 1
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49}
# random item = 45
# key = Crispy Chicken Wings
# val = 6.99
# key = Crispy Chicken Wings
# val = 6.99
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49}
# ------------------
# rnum = 1
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49, 'Crispy Chicken Wings': 6.99}
# random item = 67
# key = Black Beans
# val = 1.69
# key = Black Beans
# val = 1.69
# item_dict = {'Cheesy Toasted Breakfast Burrito Bacon': 1.49, 'Crispy Chicken Wings': 6.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 76
# key = Reduced-Fat Sour Cream
# val = 0.75
# key = Reduced-Fat Sour Cream
# val = 0.75
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Reduced-Fat Sour Cream': 0.75}
# random item = 114
# key = Taco & Burrito Cravings Pack
# val = 17.49
# key = Taco & Burrito Cravings Pack
# val = 17.49
# item_dict = {'Reduced-Fat Sour Cream': 0.75}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 52
# key = Beefy Melt Burrito
# val = 2.0
# key = Beefy Melt Burrito
# val = 2.0
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 13
# key = Breakfast Crunchwrap Sausage
# val = 3.29
# key = Breakfast Crunchwrap Sausage
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 29
# key = Nachos BellGrande Combo
# val = 10.19
# key = Nachos BellGrande Combo
# val = 10.19
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Nachos BellGrande Combo': 10.19}
# random item = 72
# key = Hot Sauce Packet
# val = 0.0
# key = Hot Sauce Packet
# val = 0.0
# item_dict = {'Nachos BellGrande Combo': 10.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 78
# key = Guacamole
# val = 0.75
# key = Guacamole
# val = 0.75
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Guacamole': 0.75}
# random item = 31
# key = Crunchwrap Supreme Combo
# val = 9.29
# key = Crunchwrap Supreme Combo
# val = 9.29
# item_dict = {'Guacamole': 0.75}
# ------------------
# rnum = 1
# item_dict = {'Guacamole': 0.75, 'Crunchwrap Supreme Combo': 9.29}
# random item = 69
# key = Pintos N Cheese
# val = 2.19
# key = Pintos N Cheese
# val = 2.19
# item_dict = {'Guacamole': 0.75, 'Crunchwrap Supreme Combo': 9.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 10
# key = Big Breakfast
# val = 4.99
# key = Big Breakfast
# val = 4.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Big Breakfast': 4.99}
# random item = 162
# key = Medium Dr. Pepper
# val = 1.79
# key = Medium Dr. Pepper
# val = 1.79
# item_dict = {'Big Breakfast': 4.99}
# ------------------
# rnum = 1
# item_dict = {'Big Breakfast': 4.99, 'Medium Dr. Pepper': 1.79}
# random item = 110
# key = Medium Iced French Vanilla Latte
# val = 3.29
# key = Medium Iced French Vanilla Latte
# val = 3.29
# item_dict = {'Big Breakfast': 4.99, 'Medium Dr. Pepper': 1.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 64
# key = Spicy Crispy Chicken Sandwich Meal
# val = 7.99
# key = Spicy Crispy Chicken Sandwich Meal
# val = 7.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Spicy Crispy Chicken Sandwich Meal': 7.99}
# random item = 18
# key = Bacon Egg Cheese McGriddle Meal
# val = 6.29
# key = Bacon Egg Cheese McGriddle Meal
# val = 6.29
# item_dict = {'Spicy Crispy Chicken Sandwich Meal': 7.99}
# ------------------
# rnum = 1
# item_dict = {'Spicy Crispy Chicken Sandwich Meal': 7.99, 'Bacon Egg Cheese McGriddle Meal': 6.29}
# random item = 185
# key = Cheeseburger
# val = 2.09
# key = Cheeseburger
# val = 2.09
# item_dict = {'Spicy Crispy Chicken Sandwich Meal': 7.99, 'Bacon Egg Cheese McGriddle Meal': 6.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 39
# key = 30 Wings Boneless
# val = 29.89
# key = 30 Wings Boneless
# val = 29.89
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 124
# key = Holiday Pie
# val = 1.59
# key = Holiday Pie
# val = 1.59
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Holiday Pie': 1.59}
# random item = 141
# key = Butter
# val = 0.0
# key = Butter
# val = 0.0
# item_dict = {'Holiday Pie': 1.59}
# ------------------
# rnum = 1
# item_dict = {'Holiday Pie': 1.59, 'Butter': 0.0}
# random item = 13
# key = Sausage Egg Biscuit Meal
# val = 5.79
# key = Sausage Egg Biscuit Meal
# val = 5.79
# item_dict = {'Holiday Pie': 1.59, 'Butter': 0.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 6
# key = Large 10 pc Wing Combo Boneless
# val = 12.29
# key = Large 10 pc Wing Combo Boneless
# val = 12.29
# item_dict = {}
# ...
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 22
# key = My Cravings Box
# val = 5.0
# key = My Cravings Box
# val = 5.0
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'My Cravings Box': 5.0}
# random item = 110
# key = Orange Juice
# val = 1.99
# key = Orange Juice
# val = 1.99
# item_dict = {'My Cravings Box': 5.0}
# ------------------
# rnum = 1
# item_dict = {'My Cravings Box': 5.0, 'Orange Juice': 1.99}
# random item = 43
# key = Black Bean Crispy Melt Taco
# val = 2.59
# key = Black Bean Crispy Melt Taco
# val = 2.59
# item_dict = {'My Cravings Box': 5.0, 'Orange Juice': 1.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 111
# key = Drinks Party Pack
# val = 4.0
# key = Drinks Party Pack
# val = 4.0
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Drinks Party Pack': 4.0}
# random item = 28
# key = Chicken Quesadilla Combo
# val = 10.19
# key = Chicken Quesadilla Combo
# val = 10.19
# item_dict = {'Drinks Party Pack': 4.0}
# ------------------
# rnum = 1
# item_dict = {'Drinks Party Pack': 4.0, 'Chicken Quesadilla Combo': 10.19}
# random item = 42
# key = Crispy Melt Taco
# val = 2.59
# key = Crispy Melt Taco
# val = 2.59
# item_dict = {'Drinks Party Pack': 4.0, 'Chicken Quesadilla Combo': 10.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 39
# key = Egg McMuffin
# val = 4.19
# key = Egg McMuffin
# val = 4.19
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 116
# key = Soft Taco Party Pack
# val = 20.99
# key = Soft Taco Party Pack
# val = 20.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Soft Taco Party Pack': 20.99}
# random item = 126
# key = Hot Cinnamon Delights Coffee
# val = 2.29
# key = Hot Cinnamon Delights Coffee
# val = 2.29
# item_dict = {'Soft Taco Party Pack': 20.99}
# ------------------
# rnum = 1
# item_dict = {'Soft Taco Party Pack': 20.99, 'Hot Cinnamon Delights Coffee': 2.29}
# random item = 1
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# key = Cheesy Toasted Breakfast Burrito Bacon
# val = 1.49
# item_dict = {'Soft Taco Party Pack': 20.99, 'Hot Cinnamon Delights Coffee': 2.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 127
# key = Equal Packet
# val = 0.0
# key = Equal Packet
# val = 0.0
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Equal Packet': 0.0}
# random item = 6
# key = Hash Browns
# val = 2.99
# key = Hash Browns
# val = 2.99
# item_dict = {'Equal Packet': 0.0}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 65
# key = Deluxe Crispy Chicken Sandwich Meal
# val = 8.79
# key = Deluxe Crispy Chicken Sandwich Meal
# val = 8.79
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Deluxe Crispy Chicken Sandwich Meal': 8.79}
# random item = 117
# key = Blueberry Muffin
# val = 2.69
# key = Blueberry Muffin
# val = 2.69
# item_dict = {'Deluxe Crispy Chicken Sandwich Meal': 8.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 78
# key = Triple Chocolate Chunk Brownie
# val = 2.09
# key = Triple Chocolate Chunk Brownie
# val = 2.09
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 77
# key = Creamy Jalapeno Sauce
# val = 0.1
# key = Creamy Jalapeno Sauce
# val = 0.1
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Creamy Jalapeno Sauce': 0.1}
# random item = 8
# key = Breakfast Quesadilla Sausage
# val = 2.89
# key = Breakfast Quesadilla Sausage
# val = 2.89
# item_dict = {'Creamy Jalapeno Sauce': 0.1}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 22
# key = Egg Biscuit Meal
# val = 3.89
# key = Egg Biscuit Meal
# val = 3.89
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Egg Biscuit Meal': 3.89}
# random item = 135
# key = Hot Mustard Dipping Sauce
# val = 0.0
# key = Hot Mustard Dipping Sauce
# val = 0.0
# item_dict = {'Egg Biscuit Meal': 3.89}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 77
# key = Soft Drinks 32oz
# val = 3.29
# key = Soft Drinks 32oz
# val = 3.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Soft Drinks 32oz': 3.29}
# random item = 62
# key = Seasoned Fries Large
# val = 4.59
# key = Seasoned Fries Large
# val = 4.59
# item_dict = {'Soft Drinks 32oz': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 105
# key = Dole Lemonade Strawberry Squeeze
# val = 2.89
# key = Dole Lemonade Strawberry Squeeze
# val = 2.89
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 21
# key = Bacon Egg Cheese Bagel Meal
# val = 5.39
# key = Bacon Egg Cheese Bagel Meal
# val = 5.39
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 49
# key = Beefy 5-Layer Burrito
# val = 3.99
# key = Beefy 5-Layer Burrito
# val = 3.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Beefy 5-Layer Burrito': 3.99}
# random item = 9
# key = Breakfast Quesadilla Bacon
# val = 2.89
# key = Breakfast Quesadilla Bacon
# val = 2.89
# item_dict = {'Beefy 5-Layer Burrito': 3.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 68
# key = Buffalo Ranch Fries Large
# val = 6.09
# key = Buffalo Ranch Fries Large
# val = 6.09
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Buffalo Ranch Fries Large': 6.09}
# random item = 70
# key = Cajun Friend Corn Large
# val = 5.19
# key = Cajun Friend Corn Large
# val = 5.19
# item_dict = {'Buffalo Ranch Fries Large': 6.09}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 63
# key = Cheese Fries Regular
# val = 3.49
# key = Cheese Fries Regular
# val = 3.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Cheese Fries Regular': 3.49}
# random item = 35
# key = 15 Wings Classic
# val = 17.49
# key = 15 Wings Classic
# val = 17.49
# item_dict = {'Cheese Fries Regular': 3.49}
# ------------------
# rnum = 1
# item_dict = {'Cheese Fries Regular': 3.49, '15 Wings Classic': 17.49}
# random item = 19
# key = 40pc Group Pack Mix & Match
# val = 52.89
# key = 40pc Group Pack Mix & Match
# val = 52.89
# item_dict = {'Cheese Fries Regular': 3.49, '15 Wings Classic': 17.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 84
# key = 4 Pieces Chicken McNuggets – Happy Meal
# val = 4.29
# key = 4 Pieces Chicken McNuggets – Happy Meal
# val = 4.29
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'4 Pieces Chicken McNuggets – Happy Meal': 4.29}
# random item = 79
# key = 40 McNuggets
# val = 12.39
# key = 40 McNuggets
# val = 12.39
# item_dict = {'4 Pieces Chicken McNuggets – Happy Meal': 4.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 4
# key = Sausage Egg Cheese McGriddle Meal
# val = 5.79
# key = Sausage Egg Cheese McGriddle Meal
# val = 5.79
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Sausage Egg Cheese McGriddle Meal': 5.79}
# random item = 61
# key = Regular Oreo McFlurry
# val = 4.29
# key = Regular Oreo McFlurry
# val = 4.29
# item_dict = {'Sausage Egg Cheese McGriddle Meal': 5.79}
# ------------------
# rnum = 1
# item_dict = {'Sausage Egg Cheese McGriddle Meal': 5.79, 'Regular Oreo McFlurry': 4.29}
# random item = 137
# key = Mustard Packet
# val = 0.0
# key = Mustard Packet
# val = 0.0
# item_dict = {'Sausage Egg Cheese McGriddle Meal': 5.79, 'Regular Oreo McFlurry': 4.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 55
# key = 24pc Crispy Tender Pack
# val = 47.19
# key = 24pc Crispy Tender Pack
# val = 47.19
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'24pc Crispy Tender Pack': 47.19}
# random item = 76
# key = Soft Drinks 20oz
# val = 2.69
# key = Soft Drinks 20oz
# val = 2.69
# item_dict = {'24pc Crispy Tender Pack': 47.19}
# ------------------
# rnum = 1
# item_dict = {'24pc Crispy Tender Pack': 47.19, 'Soft Drinks 20oz': 2.69}
# random item = 64
# key = Cheese Fries Large
# val = 5.79
# key = Cheese Fries Large
# val = 5.79
# item_dict = {'24pc Crispy Tender Pack': 47.19, 'Soft Drinks 20oz': 2.69}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 59
# key = 20 Crispy Tenders
# val = 33.69
# key = 20 Crispy Tenders
# val = 33.69
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'20 Crispy Tenders': 33.69}
# random item = 63
# key = Cheese Fries Regular
# val = 3.49
# key = Cheese Fries Regular
# val = 3.49
# item_dict = {'20 Crispy Tenders': 33.69}
# ------------------
# rnum = 1
# item_dict = {'20 Crispy Tenders': 33.69, 'Cheese Fries Regular': 3.49}
# random item = 14
# key = 24pc Family Pack Classic
# val = 34.49
# key = 24pc Family Pack Classic
# val = 34.49
# item_dict = {'20 Crispy Tenders': 33.69, 'Cheese Fries Regular': 3.49}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 110
# key = Orange Juice
# val = 1.99
# key = Orange Juice
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Orange Juice': 1.99}
# random item = 17
# key = Premium Hot Coffee
# val = 1.99
# key = Premium Hot Coffee
# val = 1.99
# item_dict = {'Orange Juice': 1.99}
# ------------------
# rnum = 1
# item_dict = {'Orange Juice': 1.99, 'Premium Hot Coffee': 1.99}
# random item = 56
# key = Veggie Mexican Pizza
# val = 4.99
# key = Veggie Mexican Pizza
# val = 4.99
# item_dict = {'Orange Juice': 1.99, 'Premium Hot Coffee': 1.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 34
# key = 3 Doritos Locos Tacos Combo
# val = 8.89
# key = 3 Doritos Locos Tacos Combo
# val = 8.89
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'3 Doritos Locos Tacos Combo': 8.89}
# random item = 65
# key = Cheesy Fiesta Potatoes
# val = 1.79
# key = Cheesy Fiesta Potatoes
# val = 1.79
# item_dict = {'3 Doritos Locos Tacos Combo': 8.89}
# ------------------
# rnum = 1
# item_dict = {'3 Doritos Locos Tacos Combo': 8.89, 'Cheesy Fiesta Potatoes': 1.79}
# random item = 53
# key = Fiesta Veggie Burrito
# val = 2.0
# key = Fiesta Veggie Burrito
# val = 2.0
# item_dict = {'3 Doritos Locos Tacos Combo': 8.89, 'Cheesy Fiesta Potatoes': 1.79}
# ------------------
# rnum = 0
# ------------------
# rnum = 1
# item_dict = {}
# random item = 31
# key = Sausage Egg Biscuit
# val = 3.99
# key = Sausage Egg Biscuit
# val = 3.99
# item_dict = {}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 58
# key = 15 Crispy Tenders
# val = 24.49
# key = 15 Crispy Tenders
# val = 24.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'15 Crispy Tenders': 24.49}
# random item = 21
# key = 50pc Party Pack Boneless
# val = 55.19
# key = 50pc Party Pack Boneless
# val = 55.19
# item_dict = {'15 Crispy Tenders': 24.49}
# ------------------
# rnum = 1
# item_dict = {'15 Crispy Tenders': 24.49, '50pc Party Pack Boneless': 55.19}
# random item = 23
# key = 50pc Party Pack Classic
# val = 65.59
# key = 50pc Party Pack Classic
# val = 65.59
# item_dict = {'15 Crispy Tenders': 24.49, '50pc Party Pack Boneless': 55.19}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 15
# key = Sausage Egg Cheese Biscuit Meal
# val = 5.99
# key = Sausage Egg Cheese Biscuit Meal
# val = 5.99
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Sausage Egg Cheese Biscuit Meal': 5.99}
# random item = 106
# key = Medium Iced Pumpkin Latte
# val = 3.29
# key = Medium Iced Pumpkin Latte
# val = 3.29
# item_dict = {'Sausage Egg Cheese Biscuit Meal': 5.99}
# ------------------
# rnum = 1
# item_dict = {'Sausage Egg Cheese Biscuit Meal': 5.99, 'Medium Iced Pumpkin Latte': 3.29}
# random item = 1
# key = Bacon Egg Cheese Biscuit Meal
# val = 6.49
# key = Bacon Egg Cheese Biscuit Meal
# val = 6.49
# item_dict = {'Sausage Egg Cheese Biscuit Meal': 5.99, 'Medium Iced Pumpkin Latte': 3.29}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 190
# key = Hamburger
# val = 1.99
# key = Hamburger
# val = 1.99
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'Hamburger': 1.99}
# random item = 153
# key = Oreo Fudge McFlurry
# val = 4.29
# key = Oreo Fudge McFlurry
# val = 4.29
# item_dict = {'Hamburger': 1.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 76
# key = Reduced-Fat Sour Cream
# val = 0.75
# key = Reduced-Fat Sour Cream
# val = 0.75
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Reduced-Fat Sour Cream': 0.75}
# random item = 116
# key = Soft Taco Party Pack
# val = 20.99
# key = Soft Taco Party Pack
# val = 20.99
# item_dict = {'Reduced-Fat Sour Cream': 0.75}
# ------------------
# rnum = 1
# item_dict = {'Reduced-Fat Sour Cream': 0.75, 'Soft Taco Party Pack': 20.99}
# random item = 101
# key = Mug Root Beer (Large)
# val = 2.89
# key = Mug Root Beer (Large)
# val = 2.89
# item_dict = {'Reduced-Fat Sour Cream': 0.75, 'Soft Taco Party Pack': 20.99}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 113
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# key = Chips And Nachos Cheese Sauce
# val = 2.19
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# random item = 48
# key = Bean Burrito
# val = 1.59
# key = Bean Burrito
# val = 1.59
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19}
# ------------------
# rnum = 1
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19, 'Bean Burrito': 1.59}
# random item = 115
# key = Supreme Taco Party Pack
# val = 27.99
# key = Supreme Taco Party Pack
# val = 27.99
# item_dict = {'Chips And Nachos Cheese Sauce': 2.19, 'Bean Burrito': 1.59}
# ------------------
# rnum = 0
# ------------------
# rnum = 2
# item_dict = {}
# random item = 32
# key = 3 Crunchy Tacos Combo
# val = 7.39
# key = 3 Crunchy Tacos Combo
# val = 7.39
# item_dict = {}
# ------------------
# rnum = 1
# item_dict = {'3 Crunchy Tacos Combo': 7.39}
# random item = 17
# key = Premium Hot Coffee
# val = 1.99
# key = Premium Hot Coffee
# val = 1.99
# item_dict = {'3 Crunchy Tacos Combo': 7.39}
# ------------------
# rnum = 0
# ------------------
# rnum = 3
# item_dict = {}
# random item = 56
# key = Double Quarter Pounder With Cheese Meal
# val = 10.49
# key = Double Quarter Pounder With Cheese Meal
# val = 10.49
# item_dict = {}
# ------------------
# rnum = 2
# item_dict = {'Double Quarter Pounder With Cheese Meal': 10.49}
# random item = 56
# key = Double Quarter Pounder With Cheese Meal
# val = 10.49
# count = 1
# it is duplicate
# item_dict = {'Double Quarter Pounder With Cheese Meal': 10.49}
# item_dict = None
# ------------------
# rnum = 1
# item_dict = None
# random item = 90
# key = Medium Iced Caramel Coffee
# val = 2.69
# key = Medium Iced Caramel Coffee
# val = 2.69
# item_dict = None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24296\2275320395.py in <module>
#      13
#      14
# ---> 15     item_dict = get_item_dict(vendor_id, 1,4)
#      16     item_csv = get_csv_from_dict(item_dict)
#      17     col_4=item_csv
#
# ~\AppData\Local\Temp\ipykernel_24296\2164105881.py in get_item_dict(vendor_id, start, end)
#       5
#       6     item_dict={}
# ----> 7     item_dict = getItemList(menu_dict,items_ordered, item_dict)
#       8
#       9     return item_dict
#
# ~\AppData\Local\Temp\ipykernel_24296\1040647190.py in getItemList(menu, rnum, item_dict)
#       5     if(rnum > 0):
#       6         item_dict = addItem(item_dict, menu)
# ----> 7         getItemList(menu, rnum-1, item_dict)
#       8     return item_dict
#
# ~\AppData\Local\Temp\ipykernel_24296\1040647190.py in getItemList(menu, rnum, item_dict)
#       5     if(rnum > 0):
#       6         item_dict = addItem(item_dict, menu)
# ----> 7         getItemList(menu, rnum-1, item_dict)
#       8     return item_dict
#
# ~\AppData\Local\Temp\ipykernel_24296\1040647190.py in getItemList(menu, rnum, item_dict)
#       4     item_dict = item_dict
#       5     if(rnum > 0):
# ----> 6         item_dict = addItem(item_dict, menu)
#       7         getItemList(menu, rnum-1, item_dict)
#       8     return item_dict
#
# ~\AppData\Local\Temp\ipykernel_24296\907029361.py in addItem(item_dict, menu)
#      41         print(f"val = {val}")
#      42         print(f"item_dict = {item_dict}")
# ---> 43         item_dict[key]=val
#      44
#      45     #except (Exception) as error:
#
# TypeError: 'NoneType' object does not support item assignment

# %%
column_values = f" {col_2} , '{col_3}' , '{col_4}' ,'{col_5}' ,{col_6} ,{col_7} ,'{col_8}', {col_9}"

print(column_values)

# %%
def get_last_row(cur):
    #get last row of user_purchase
    query = """SELECT * FROM user_purchase
    WHERE invoice_number=(SELECT max(invoice_number) FROM user_purchase);
    """
    cur.execute(query)
    result = cur.fetchone()
    return result

# %%
result = get_last_row(cur)
print(result[0])

# %%
def get_all_records(cur):
    query = """SELECT * FROM user_purchase;"""
    cur.execute(query)
    result = cur.fetchall()
    return result

# %%
print(get_all_records(cur))

# %%
#Closing the connection
conn.close()
